# %%
with open('/nfs/gpu_trainee/getp02/gpt-oss/data/output.txt','r') as f:
    lines = f.readlines()

# %%
for line in lines:
    print(len(line.split()))
# Out:
# 1024
# 1023
# 1016
# 1020
# 144
# 1018
# 1020
# 1022
# 1023
# 1023
# 1021
# 1007
# 1019
# 1015
# 1021
# 1008
# 1022
# 1021
# 1021
# 437
# 1022
# 1020
# 1014
# 1014
# 984
# 1012
# 1013
# 1009
# 1014
# 1014
# 1011
# 1015

# %%
lines_truncated = [' '.join(x) for x in [line.split()[:100] for line in lines]]

# %%
lines_truncated[0]
# Out:
# '11 5922 0 12263 17045 1402 168394 12996 198 561 1333 5040 8646 9729 6631 3960 8146 307 561 1333 5040 8646 9729 6631 45915 2947 502 59402 2947 198 1154 744 32949 2947 405 1944 271 759 1816 8146 6867 24912 1896 271 751 1189 40617 416 405 309'

# %%
with open('/nfs/gpu_trainee/getp02/gpt-oss/data/output_truncated_100.txt','w') as f:
    f.writelines('\n'.join(lines_truncated))
